# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
import missingno as mino

# %%
car = pd.read_csv("car.csv")

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
car.shape
# Out:
# (205, 26)

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
car.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
pd.DataFrame(car.kurtosis(),columns=['kurtosis'])
# Out:
#                   kurtosis
# car_ID           -1.200000
# symboling        -0.676271
# wheelbase         1.017039
# carlength        -0.082895
# carwidth          0.702764
# carheight        -0.443812
# curbweight       -0.042854
# enginesize        5.305682
# boreratio        -0.785042
# stroke            2.174396
# compressionratio  5.233054
# horsepower        2.684006
# peakrpm           0.086756
# citympg           0.578648
# highwaympg        0.440070
# price             3.051648

# %%
pd.DataFrame(car.skew(),columns=['skewness'])
# Out:
#                   skewness
# car_ID            0.000000
# symboling         0.211072
# wheelbase         1.050214
# carlength         0.155954
# carwidth          0.904003
# carheight         0.063123
# curbweight        0.681398
# enginesize        1.947655
# boreratio         0.020156
# stroke           -0.689705
# compressionratio  2.610862
# horsepower        1.405310
# peakrpm           0.075159
# citympg           0.663704
# highwaympg        0.539997
# price             1.777678

# %%
car.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car.columns=car.columns.str.replace(' ','')
car.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
mino.matrix(car)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=car , kind='box' , height=7, aspect=2.5)

# %% [markdown]
# ### Univariate analysis

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
sns.boxplot(x='wheelbase',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='price'>

# %%
sns.scatterplot(x='wheelbase',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='price'>

# %%
sns.scatterplot(x='enginesize',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='price'>

# %%
sns.scatterplot(x='boreratio',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='price'>

# %%
sns.scatterplot(x='stroke',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
sns.scatterplot(x='compressionratio',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='compressionratio', ylabel='price'>

# %%
sns.scatterplot(x='horsepower',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
sns.scatterplot(x='peakrpm',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='peakrpm', ylabel='price'>

# %%
sns.scatterplot(x='citympg',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='citympg', ylabel='price'>

# %%
sns.scatterplot(x='highwaympg',y='price',data=car)
# Out:
# <AxesSubplot:xlabel='highwaympg', ylabel='price'>

# %%
sns.pairplot(car,height=2,diag_kind='hist')

# %%
sns.pairplot(car,height=2,diag_kind='kde')

# %%
car.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
car.cov()
# Out:
#                         car_ID   symboling     wheelbase     carlength  \
# car_ID             3519.166667  -11.200980     46.342647    124.885294
# symboling           -11.200980    1.550789     -3.989099     -5.494240
# wheelbase            46.342647   -3.989099     36.261782     64.975189
# carlength           124.885294   -5.494240     64.975189    152.208688
# carwidth              6.666667   -0.622229     10.271615     22.261035
# carheight            37.102941   -1.646344      8.673144     14.802788
# curbweight         2222.754902 -147.636083   2434.296746   5638.336200
# enginesize          -83.818627   -5.486035    142.766545    351.081549
# boreratio             4.178480   -0.043864      0.797132      2.026453
# stroke               -2.991863   -0.003411      0.303957      0.501153
# compressionratio     35.409755   -0.883009      5.974562      7.762938
# horsepower          -35.200980    3.490100     84.128637    269.606949
# ...

# %%
sns.heatmap(car.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
def deleteStringColumns(df):
    col = list(df.select_dtypes(include='object').columns)
    df = df.drop(col,axis=1)
    return df

# %%
d=deleteStringColumns(car)
df=d.drop(['car_ID','symboling'],axis=1)
df
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
df.shape
# Out:
# (205, 14)

# %%
df.isnull().sum()
# Out:
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # ModelBuilding

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X=df.drop(['price'],axis=1)
y=df['price']

# %%
lr=LinearRegression(normalize=True)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)
y_test
# Out:
# 52      6795.0
# 181    15750.0
# 5      15250.0
# 18      5151.0
# 188     9995.0
# 170    11199.0
# 76      5389.0
# 154     7898.0
# 104    17199.0
# 33      6529.0
# 12     20970.0
# 129    31400.5
# 55     10945.0
# 66     18344.0
# 45      8916.5
# 169     9989.0
# 130     9295.0
# 7      18920.0
# 37      7895.0
# 152     6488.0
# 80      9959.0
# 111    15580.0
# 131     9895.0
# 171    11549.0
# 179    15998.0
# 138     5118.0
# 156     6938.0
# 113    16695.0
# 161     8358.0
# 89      5499.0
# 183     7975.0
# 193    12290.0
# 125    22018.0
# 173     8948.0
# 92      6849.0
# 16     41315.0
# 189    11595.0
# 136    18150.0
# 22      6377.0
# 74     45400.0
# 44      8916.5
# Name: price, dtype: float64

# %%
test=lr.fit(X_train,y_train)

# %%
pred=lr.predict(X_test)

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': pred})
df1
# Out:
#       Actual     Predicted
# 52    6795.0   6208.245755
# 181  15750.0  19714.877037
# 5    15250.0  15087.299046
# 18    5151.0  -1452.379476
# 188   9995.0  11257.617135
# 170  11199.0  13442.051176
# 76    5389.0   5943.643867
# 154   7898.0   6224.403638
# 104  17199.0  23366.845409
# 33    6529.0   8482.534509
# 12   20970.0  15731.584206
# 129  31400.5  37414.864535
# 55   10945.0   9507.440936
# 66   18344.0  13745.157704
# 45    8916.5   5786.726145
# 169   9989.0  13118.070716
# 130   9295.0  11254.893431
# 7    18920.0  19283.345850
# 37    7895.0  10296.268572
# 152   6488.0   6072.450747
# 80    9959.0  10655.338424
# 111  15580.0  18077.000577
# 131   9895.0  10915.008166
# 171  11549.0  13530.639583
# 179  15998.0  21590.865712
# 138   5118.0   8044.257101
# 156   6938.0   6724.496922
# 113  16695.0  17715.147722
# 161   8358.0   6824.589377
# 89    5499.0   5799.253493
# 183   7975.0   9719.423779
# 193  12290.0  11296.381773
# 125  22018.0  21201.435601
# ...

# %%
print(lr.intercept_)
# Out:
# -56723.36209174819

# %%
df2 = pd.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
df2
# Out:
#                   Coefficient
# wheelbase           71.508801
# carlength         -110.154815
# carwidth           780.586995
# carheight          134.993832
# curbweight           2.531097
# enginesize          99.578546
# boreratio         -777.574037
# stroke           -2995.119872
# compressionratio   297.504802
# horsepower          35.936382
# peakrpm              2.288345
# citympg           -348.952373
# highwaympg         224.862839

# %%
from sklearn.metrics import r2_score

# %%
r2_score=r2_score(y_test,pred)
r2_score
# Out:
# 0.8181813278710409

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 2559.412914616056
# MSE: 14075739.453018257
# RMSE: 3751.7648451119985

# %% [markdown]
# ### OLS Method

# %%
import statsmodels.api as sm
#splitting the dataset into train and test
X=sm.add_constant(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)
print(X)
# Out:
#      const  wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0      1.0       88.6      168.8      64.1       48.8        2548         130
# 1      1.0       88.6      168.8      64.1       48.8        2548         130
# 2      1.0       94.5      171.2      65.5       52.4        2823         152
# 3      1.0       99.8      176.6      66.2       54.3        2337         109
# 4      1.0       99.4      176.6      66.4       54.3        2824         136
# ..     ...        ...        ...       ...        ...         ...         ...
# 200    1.0      109.1      188.8      68.9       55.5        2952         141
# 201    1.0      109.1      188.8      68.8       55.5        3049         141
# 202    1.0      109.1      188.8      68.9       55.5        3012         173
# 203    1.0      109.1      188.8      68.9       55.5        3217         145
# 204    1.0      109.1      188.8      68.9       55.5        3062         141
#
# ...

# %%
import statsmodels.api as sm
from scipy import stats
model_ols=sm.OLS(y_train,X_train).fit()

# %%
print(model_ols.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     69.16
# Date:                Tue, 02 Nov 2021   Prob (F-statistic):           1.73e-56
# Time:                        23:12:58   Log-Likelihood:                -1541.9
# No. Observations:                 164   AIC:                             3112.
# Df Residuals:                     150   BIC:                             3155.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -5.672e+04   1.76e+04     -3.225      0.002   -9.15e+04    -2.2e+04
# ...

# %%
y_pred=model_ols.predict(X_train)
pd.DataFrame(y_pred,columns=['Train_data_predicted_values'])
# Out:
#      Train_data_predicted_values
# 4                   15883.506416
# 71                  30986.696202
# 134                 17717.977173
# 145                 11442.467962
# 122                  7081.330092
# ..                           ...
# 67                  24765.646873
# 192                 10541.764451
# 117                 19267.711345
# 47                  30139.563146
# 172                 14326.249821
#
# [164 rows x 1 columns]

# %%
pd.DataFrame({'predicted_train_values':y_pred,'Actual__train_values':y_train})
# Out:
#      predicted_train_values  Actual__train_values
# 4              15883.506416               17450.0
# 71             30986.696202               34184.0
# 134            17717.977173               15040.0
# 145            11442.467962               11259.0
# 122             7081.330092                7609.0
# ..                      ...                   ...
# 67             24765.646873               25552.0
# 192            10541.764451               13845.0
# 117            19267.711345               18150.0
# 47             30139.563146               32250.0
# 172            14326.249821               17669.0
#
# [164 rows x 2 columns]

# %%
df_pred=model_ols.predict(X_test)
pd.DataFrame(df_pred,columns=['Test_data_predicted_values'])
# Out:
#      Test_data_predicted_values
# 52                  6208.245755
# 181                19714.877037
# 5                  15087.299046
# 18                 -1452.379476
# 188                11257.617135
# 170                13442.051176
# 76                  5943.643867
# 154                 6224.403638
# 104                23366.845409
# 33                  8482.534509
# 12                 15731.584206
# 129                37414.864535
# 55                  9507.440936
# 66                 13745.157704
# 45                  5786.726145
# 169                13118.070716
# 130                11254.893431
# 7                  19283.345850
# 37                 10296.268572
# 152                 6072.450747
# 80                 10655.338424
# 111                18077.000577
# 131                10915.008166
# 171                13530.639583
# 179                21590.865712
# 138                 8044.257101
# 156                 6724.496922
# 113                17715.147722
# ...

# %%
pd.DataFrame({'Predicted_test_values':df_pred,'Actual__test_values':y_test})
# Out:
#      Predicted_test_values  Actual__test_values
# 52             6208.245755               6795.0
# 181           19714.877037              15750.0
# 5             15087.299046              15250.0
# 18            -1452.379476               5151.0
# 188           11257.617135               9995.0
# 170           13442.051176              11199.0
# 76             5943.643867               5389.0
# 154            6224.403638               7898.0
# 104           23366.845409              17199.0
# 33             8482.534509               6529.0
# 12            15731.584206              20970.0
# 129           37414.864535              31400.5
# 55             9507.440936              10945.0
# 66            13745.157704              18344.0
# 45             5786.726145               8916.5
# 169           13118.070716               9989.0
# 130           11254.893431               9295.0
# 7             19283.345850              18920.0
# 37            10296.268572               7895.0
# ...

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, df_pred))
print('MSE:', metrics.mean_squared_error(y_test, df_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, df_pred)))
# Out:
# MAE: 2559.4129146160385
# MSE: 14075739.453018302
# RMSE: 3751.7648451120044

# %%
print('MAE:', metrics.mean_absolute_error(y_train, y_pred))
print('MSE:', metrics.mean_squared_error(y_train, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# MAE: 2197.4616949592614
# MSE: 8583524.536505735
# RMSE: 2929.7652698647607

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["VIF Predictors"] = X.columns
vif
# Out:
#      VIF Factor    VIF Predictors
# 0   4699.328071             const
# 1      7.340949         wheelbase
# 2      9.422999         carlength
# 3      5.586367          carwidth
# 4      2.205975         carheight
# 5     16.413371        curbweight
# 6      6.658982        enginesize
# 7      2.103912         boreratio
# 8      1.195781            stroke
# 9      2.175511  compressionratio
# 10     8.247880        horsepower
# 11     2.053763           peakrpm
# 12    27.128671           citympg
# 13    24.277439        highwaympg

# %%
import numpy as np

# %%
df.head()
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
# 1       88.6      168.8      64.1       48.8        2548         130
# 2       94.5      171.2      65.5       52.4        2823         152
# 3       99.8      176.6      66.2       54.3        2337         109
# 4       99.4      176.6      66.4       54.3        2824         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# ...

# %% [markdown]
# # ols method prediction

# %%
print('Enter Below values to predict the CAR price')
Constant=float(input('Enter Value for Constant: '))
Wheelbase=float(input('Enter Value for Wheelbase: '))
Carlength=float(input('Enter Value for Carlength: '))
Carwidth=float(input('Enter Value for Carwidth: '))
Carheight=float(input('Enter Value for Carheight: '))
Curbweight=float(input('Enter Value for Curbweight: '))
Enginesize=float(input('Enter Value for Enginesize: '))
Boreratio=float(input('Enter Value for Boreratio: '))
Stroke=float(input('Enter Value for Stroke: '))
Compressionratio=float(input('Enter Value for Compressionratio: '))
Horsepower=float(input('Enter Value for Horsepower: '))
Peakrpm=float(input('Enter Value for Peakrpm: '))
Citympg=float(input('Enter Value for Citympg: '))
Highwaympg=float(input('Enter Value for Highwaympg: '))
my_array = np.array([Constant,Wheelbase,Carlength,Carwidth,Carheight,Curbweight,Enginesize,Boreratio,Stroke,Compressionratio,Horsepower,Peakrpm,Citympg,Highwaympg])
print('predicted Value for CAR price',model_ols.predict(my_array.reshape(1, -1)))
# Out:
# Enter Below values to predict the CAR price
# Enter Value for Constant: 1
# Enter Value for Wheelbase: 88.6
# Enter Value for Carlength: 168.8
# Enter Value for Carwidth: 64.1
# Enter Value for Carheight: 48.8
# Enter Value for Curbweight: 2548
# Enter Value for Enginesize: 130
# Enter Value for Boreratio: 3.47
# Enter Value for Stroke: 2.68
# Enter Value for Compressionratio: 9.0
# Enter Value for Horsepower: 111
# Enter Value for Peakrpm: 5000
# Enter Value for Citympg: 21
# Enter Value for Highwaympg: 27
# predicted Value for CAR price [13162.35799226]

# %% [markdown]
# # sklearn method prediction

# %%
print('Enter Below values to predict the CAR price')
Wheelbase=float(input('Enter Value for Wheelbase: '))
Carlength=float(input('Enter Value for Carlength: '))
Carwidth=float(input('Enter Value for Carwidth: '))
Carheight=float(input('Enter Value for Carheight: '))
Curbweight=float(input('Enter Value for Curbweight: '))
Enginesize=float(input('Enter Value for Enginesize: '))
Boreratio=float(input('Enter Value for Boreratio: '))
Stroke=float(input('Enter Value for Stroke: '))
Compressionratio=float(input('Enter Value for Compressionratio: '))
Horsepower=float(input('Enter Value for Horsepower: '))
Peakrpm=float(input('Enter Value for Peakrpm: '))
Citympg=float(input('Enter Value for Citympg: '))
Highwaympg=float(input('Enter Value for Highwaympg: '))
my_array = np.array([Wheelbase,Carlength,Carwidth,Carheight,Curbweight,Enginesize,Boreratio,Stroke,Compressionratio,Horsepower,Peakrpm,Citympg,Highwaympg])
print('predicted Value for CAR price',lr.predict(my_array.reshape(1, -1)))
# Out:
# Enter Below values to predict the CAR price
# Enter Value for Wheelbase: 88.6
# Enter Value for Carlength: 168.8
# Enter Value for Carwidth: 64.1
# Enter Value for Carheight: 48.8
# Enter Value for Curbweight: 2548
# Enter Value for Enginesize: 130
# Enter Value for Boreratio: 3.47
# Enter Value for Stroke: 2.68
# Enter Value for Compressionratio: 9.0
# Enter Value for Horsepower: 111
# Enter Value for Peakrpm: 5000
# Enter Value for Citympg: 21
# Enter Value for Highwaympg: 27
# predicted Value for CAR price [13162.35799226]

# %%
import lmdiag

# %%
lmdiag.plot(model_ols)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\NIHAR\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
lmdiag.resid_fit(model_ols)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\NIHAR\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
lmdiag.q_q(model_ols)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\NIHAR\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
lmdiag.scale_loc(model_ols)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\NIHAR\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
lmdiag.resid_lev(model_ols)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\NIHAR\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sm.graphics.influence_plot(model_ols)
